# %% [markdown]
# # Bimodal Gaussian Posterior - NPE_A method

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('..'))

# %%
import lfi
import torch
import numpy as np
# Out:
# WARNING (pytensor.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# WARNING (pytensor.configdefaults): g++ not detected!  PyTensor will be unable to compile C-implementations and will default to Python. Performance may be severely degraded. To remove this warning, set PyTensor flags cxx to an empty string.
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
from lfi import priors, simulators
import lfi.inference.from_sbi

# %% [markdown]
# ## D=2
#
# ### Success: 500

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 2
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
print(prior)
# Out:
# <lfi.priors.UniformPrior object at 0x00000177F6345750>

# %%
print(prior.return_sbi_object())
# Out:
# BoxUniform(Uniform(low: torch.Size([2]), high: torch.Size([2])), 1)

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=500, num_samples=100)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#  Neural network successfully converged after 576 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 9.90 seconds

# %%
inference.plot_training_summary(budget=500, num_components=10)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=2, budget=500, num_components =10'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=500,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=10,
)

# %% [markdown]
# ### budget: 500
#
# #### num_components: 2

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 2
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=500, num_samples=100, num_components=2)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#  Neural network successfully converged after 438 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 7.81 seconds

# %%
inference.plot_training_summary(budget=500, num_components=2)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=2, budget=500, num_components =2'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=500,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components = 2,
)

# %% [markdown]
# ### budget: 500
#
# #### num_components=5

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 2
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=500, num_samples=100, num_components=5)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#  Training neural network. Epochs trained: 1001
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 16.34 seconds

# %%
inference.plot_training_summary(budget=500, num_components=5)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=2, budget=500, num_components =5'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=500,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=5,
)

# %% [markdown]
# ### budget: 5000
#
# #### num_components=10

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 2
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=5000, num_samples=100)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
#  Neural network successfully converged after 233 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 34.92 seconds

# %%
inference.plot_training_summary(budget=5_000, num_components=10)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=2, budget=5000, num_components =10'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=5000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=10,
)

# %% [markdown]
# ### budget: 5000
#
# #### num_components = 2

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 2
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=5000, num_samples=100, num_components=2)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
#  Neural network successfully converged after 155 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 20.68 seconds

# %%
inference.plot_training_summary(budget=5_000, num_components=2)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=2, budget=5000, num_components =2'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=5000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=2,
)

# %% [markdown]
# ### budget: 5000
#
# #### num_components = 5

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 2
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=5_000, num_samples=100, num_components=5)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
#  Neural network successfully converged after 194 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 27.04 seconds

# %%
inference.plot_training_summary(budget=5_000, num_components=5)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=2, budget=5000, num_components =5'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=5000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=5,
)

# %% [markdown]
# # D = 5
# ## budget: 1000

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 5
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=1000, num_samples=100)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#  Neural network successfully converged after 696 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 16.20 seconds

# %%
inference.plot_training_summary(budget=1_000, num_components=10)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=5, budget=1000, num_components =10'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=1000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=10
)

# %% [markdown]
# ### budget: 1_000
#
# #### num_components: 15

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 5
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=1000, num_samples=100, num_components=15)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#  Neural network successfully converged after 612 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 14.39 seconds

# %%
inference.plot_training_summary(budget=1000, num_components=15)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=5, budget=1000, num_components =15'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=1000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=15
)

# %% [markdown]
# ## D = 5
#
# ### budget: 10_000

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 5
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=10000, num_samples=100)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#  Neural network successfully converged after 256 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 85.83 seconds

# %%
inference.plot_training_summary(budget=10_000)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=5, budget=10000'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=10000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
)

# %% [markdown]
# ### budget: 10_000
#
# #### num_components = 15

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 5
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=10_000, num_samples=100, num_components=15)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#  Neural network successfully converged after 256 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 91.05 seconds

# %%
inference.plot_training_summary(budget=10_000, num_components=15)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=5, budget=10000, num_components =15'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=10000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components = 15,
)

# %% [markdown]
# ### budget: 20_000

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 5
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=20000, num_samples=100)
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
#  Neural network successfully converged after 171 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 114.41 seconds

# %%
inference.plot_training_summary(budget=20_000)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=5, budget=20000'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=20000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
)

# %% [markdown]
# ### budget: 20_000
#
# #### num_components = 20

# %%
np.random.normal(21355)
torch.manual_seed(21)

# %%
D = 5
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=20000, num_samples=100, num_components=20)
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
#  Neural network successfully converged after 142 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 111.61 seconds

# %%
inference.plot_training_summary(budget=20_000, num_components=20)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=5, budget=20000, num_components =20'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=20000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components = 20,
)

# %% [markdown]
# ### budget: 30_000

# %%
np.random.normal(21355)
torch.manual_seed(21)

# %%
D = 5
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=30000, num_samples=100)
# Out:
#   0%|          | 0/30000 [00:00<?, ?it/s]
#  Neural network successfully converged after 135 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 134.85 seconds

# %%
inference.plot_training_summary(budget=30_000)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=5, budget=30000'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=30000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
)

# %% [markdown]
# ### budget: 50_000
#
# #### num_components = 10

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 5
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=50000, num_samples=100, num_components=10)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
#  Neural network successfully converged after 144 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 259.20 seconds

# %%
inference.plot_training_summary(budget=50_000, num_components=10)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=5, budget=50000, num_components =10'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=50000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=10,
)

# %% [markdown]
# ### budget = 100_000
#
# #### num_components = 10

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 5
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=100000, num_samples=100, num_components=10)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
#  Neural network successfully converged after 72 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 265.32 seconds

# %%
inference.plot_training_summary(budget=100_000, num_components=10)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=5, budget=100000, num_components =10'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=100_000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=10,
)

# %% [markdown]
# ### budget=30_000
#
# #### num_components=20

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 5
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=30000, num_samples=100, num_components=20)
# Out:
#   0%|          | 0/30000 [00:00<?, ?it/s]
#  Neural network successfully converged after 132 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 151.06 seconds

# %%
inference.plot_training_summary(budget=30_000, num_components=20)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=5, budget=30000, num_components =20'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=30000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=20,
)

# %% [markdown]
# ## D = 3
#
# ### budget: 5000

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 3
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=5000, num_samples=100)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
#  Neural network successfully converged after 97 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 15.46 seconds

# %%
inference.plot_training_summary(budget=5000, num_components=10)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=3, budget=5000, num_components =10'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=5000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=10
)

# %% [markdown]
# ### budget: 5000
#
# #### num_components: 20

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 3
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=5000, num_samples=100, num_components=20)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
#  Neural network successfully converged after 166 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 28.78 seconds

# %%
inference.plot_training_summary(budget=5_000, num_components = 20)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=3, budget=5000, num_components =20'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=5000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=20
)

# %% [markdown]
# ### budget: 10000
#
# #### num_components: 10

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 3
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=10000, num_samples=100)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#  Neural network successfully converged after 217 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 67.88 seconds

# %%
inference.plot_training_summary(budget=10000, num_components=10)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=3, budget=10000, num_components =10'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=10000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=10,
)

# %% [markdown]
# ### budget: 10_000
#
# #### num_components: 5

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 3
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=10000, num_samples=100, num_components=5)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#  Neural network successfully converged after 250 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 72.29 seconds

# %%
inference.plot_training_summary(budget=10000, num_components=5)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=3, budget=10000, num_components =5'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=10000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=5,
)

# %% [markdown]
# ### budget: 10_000
#
# #### num_components: 2

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 3
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=10_000, num_samples=100, num_components=2)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#  Neural network successfully converged after 131 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 36.38 seconds

# %%
inference.plot_training_summary(budget=10000, num_components=2)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=3, budget=10000, num_components =2'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=10000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=2,
)

# %% [markdown]
# ### budget: 20_000
#
# #### num_components: 10

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 3
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=20000, num_samples=100)
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
#  Neural network successfully converged after 199 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 124.41 seconds

# %%
inference.plot_training_summary(budget=20_000, num_components=10)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=3, budget=20000, num_components =10'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=20000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=10,
)

# %% [markdown]
# ### budget: 20_000
#
# ### num_components: 5

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 3
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=20000, num_samples=100, num_components=5)
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
#  Neural network successfully converged after 159 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 91.63 seconds

# %%
inference.plot_training_summary(budget=20000, num_components=5)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=3, budget=20000, num_components =5'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=20000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=5,
)

# %% [markdown]
# ### budget: 20_000
#
# #### num_components: 2

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 3
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=20000, num_samples=100, num_components=2)
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
#  Neural network successfully converged after 129 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 71.18 seconds

# %%
inference.plot_training_summary(budget=20000, num_components=2)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=3, budget=20000, num_components =2'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=20000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=2,
)

# %% [markdown]
# ### budget: 30_000

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 3
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=30000, num_samples=100)
# Out:
#   0%|          | 0/30000 [00:00<?, ?it/s]
#  Neural network successfully converged after 134 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 126.21 seconds

# %%
inference.plot_training_summary(budget=30_000)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=3, budget=30000'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=30000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
)

# %% [markdown]
# ### budget: 30_000
#
# #### num_components: 5

# %%
np.random.seed(21355)
torch.manual_seed(21)

# %%
D = 3
sim = lfi.simulators.BimodalGaussian(sigma_noise=0.1)
prior = lfi.priors.UniformPrior(low=-10, high=10, dim=D)
observation = np.zeros((1,D))
posterior_modes = np.ones((2,D))
posterior_modes[0, :] = -3
posterior_modes[1, :] = 3

# %%
inference = lfi.inference.from_sbi.NPEASingleRound(
    prior=prior.return_sbi_object(),
    simulator=sim.sample_pytorch,
    observation = observation,
)

# %%
samples, time = inference.fit_and_sample(budget=30000, num_samples=100, num_components=5)
# Out:
#   0%|          | 0/30000 [00:00<?, ?it/s]
#  Neural network successfully converged after 125 epochs.
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Training/Sampling time: 107.97 seconds

# %%
inference.plot_training_summary(budget=30_000, num_components=5)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'NPE-A (single round): D=3, budget=30000, num_components =5'}, xlabel='Epoch', ylabel='Loss = Negative Log Likelihood'>)

# %%
g = inference.plot_posterior_samples(
    samples=samples,
    budget=30000,
    posterior_modes=posterior_modes,
    subset_dims=[d for d in range(D)],
    num_components=5,
)
